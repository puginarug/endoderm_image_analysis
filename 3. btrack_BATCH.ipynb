# %%
import btrack
from skimage.io import imread
import os

# %%
WORKING_DIR = r'D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2'
BINARY_SEG_FOLDER = WORKING_DIR+'\\cellpose_segmentation'
CONFIG_FILE = r'D:\David\THESIS\code\3.1 cell_config_david.json'

# %%
# collect segmentation files
segmentation_files = [os.path.join(BINARY_SEG_FOLDER, f) for f in os.listdir(BINARY_SEG_FOLDER) if f.endswith('.tif')]
segmentation_files.sort()

# %%
# select features for btrack
FEATURES = [
  "area",
  "major_axis_length",
  "minor_axis_length",
]

# %%
# create a working directory for the tracks
if not os.path.exists(os.path.join(WORKING_DIR, 'btrack_tracks')):
    os.makedirs(os.path.join(WORKING_DIR, 'btrack_tracks'))

# %%
# for seg_file in segmentation_files:
#     # print(seg_file.split('position')[1].split('_')[1])

# %%
# loop over the segmentation files (key = file, value = list of object counts)
objects_counts = {}

for seg_file in segmentation_files:
    print(f"Processing {seg_file}...")
    
    # load the segmentation data
    segmentation = imread(seg_file)
    # segmentation = segmentation[:, :, :, 0] # is using segmented data from ilatik - use this line to remove the z dimension
    # create btrack objects (with properties) from the segmentation data
    objects = btrack.utils.segmentation_to_objects(
        segmentation,
        properties=tuple(FEATURES), 
        num_workers=10,  # parallelise this
    )

    # store object count for each frame in a list and add list to dictionary
    objects_counts[seg_file] = len(objects)

    # initialise a tracker session using a context manager
    with btrack.BayesianTracker() as tracker:

        # configure the tracker using a config file
        tracker.configure(CONFIG_FILE)
        tracker.max_search_radius = 75
        tracker.tracking_updates = ["MOTION"]
        tracker.features = FEATURES

        # append the objects to be tracked
        tracker.append(objects)

        # set the tracking volume
        tracker.volume=((0, segmentation.shape[2]), (0, segmentation.shape[1]))
        
        # track them (in interactive mode)
        tracker.track(step_size=100)

        # generate hypotheses and run the global optimizer
        tracker.optimize()

        # get the tracks in a format for napari visualization
        data, properties, graph = tracker.to_napari()
        
        # store the tracks
        tracks = tracker.tracks
        
        # store the configuration
        cfg = tracker.configuration
        
        # export the track data
        position_number = seg_file.split('xy')[1].split('_')[0]
        tracker.export(
            os.path.join(WORKING_DIR, 'btrack_tracks_centers', f'tracks_{position_number}.h5'),
            obj_type="obj_type_1"
        )
# Out:
# Processing D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\cellpose_SAM_segmented_centers\3_centers\220125_2dfacs_foxa2positive_lateday2_xy01_max_projection_centers.tif...
# [INFO][2025/10/18 02:38:04 PM] Localizing objects from segmentation...
# [INFO][2025/10/18 02:38:04 PM] Processing using 10 workers.
# 100%|██████████| 241/241 [00:10<00:00, 23.44it/s]
# [INFO][2025/10/18 02:38:15 PM] Objects are of type: <class 'dict'>
# [INFO][2025/10/18 02:38:15 PM] ...Found 86704 objects in 241 frames.
# [INFO][2025/10/18 02:38:15 PM] Loaded btrack: C:\Users\davidzi\AppData\Local\anaconda3\envs\btrack-env\Lib\site-packages\btrack\libs\libtracker.DLL
# [INFO][2025/10/18 02:38:15 PM] Starting BayesianTracker session
# [INFO][2025/10/18 02:38:15 PM] Loading configuration file: D:\David\THESIS\code\3.1 cell_config_david.json
# [INFO][2025/10/18 02:38:15 PM] Objects are of type: <class 'list'>
# [INFO][2025/10/18 02:38:16 PM] Starting tracking...
# [INFO][2025/10/18 02:38:16 PM] Update using: ['MOTION']
# [INFO][2025/10/18 02:38:16 PM] Tracking objects in frames 0 to 99 (of 241)...
# [INFO][2025/10/18 02:38:24 PM]  - Timing (Bayesian updates: 77.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:38:24 PM]  - Probabilities (Link: 0.99955, Lost: 1.00000)
# [INFO][2025/10/18 02:38:24 PM]  - Stats (Active: 514, Lost: 17293, Conflicts resolved: 206)
# [INFO][2025/10/18 02:38:24 PM] Tracking objects in frames 100 to 199 (of 241)...
# [INFO][2025/10/18 02:38:35 PM]  - Timing (Bayesian updates: 106.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:38:35 PM]  - Probabilities (Link: 0.99946, Lost: 0.89767)
# [INFO][2025/10/18 02:38:35 PM]  - Stats (Active: 611, Lost: 39932, Conflicts resolved: 382)
# [INFO][2025/10/18 02:38:35 PM] Tracking objects in frames 200 to 241 (of 241)...
# [INFO][2025/10/18 02:38:39 PM]  - Timing (Bayesian updates: 135.00ms, Linking: 3.00ms)
# [INFO][2025/10/18 02:38:39 PM]  - Probabilities (Link: 0.99988, Lost: 1.00000)
# [INFO][2025/10/18 02:38:39 PM] SUCCESS.
# [INFO][2025/10/18 02:38:39 PM]  - Found 8288 tracks in 241 frames (in 0.0s)
# [INFO][2025/10/18 02:38:39 PM]  - Inserted 5537 dummy objects to fill tracking gaps
# [INFO][2025/10/18 02:38:39 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2025/10/18 02:38:39 PM] Calculating hypotheses (relax: True)...
# [INFO][2025/10/18 02:38:39 PM] Setting up constraints matrix for global optimisation...
# [INFO][2025/10/18 02:38:40 PM] Optimizing...
# [INFO][2025/10/18 02:38:41 PM] Optimization complete. (Solution: optimal)
# [INFO][2025/10/18 02:38:41 PM]  - Fates.FALSE_POSITIVE: 2832 (of 8288)
# [INFO][2025/10/18 02:38:41 PM]  - Fates.LINK: 2427 (of 4675)
# [INFO][2025/10/18 02:38:41 PM]  - Fates.DIVIDE: 545 (of 627)
# [INFO][2025/10/18 02:38:41 PM]  - Fates.INITIALIZE_BORDER: 123 (of 296)
# [INFO][2025/10/18 02:38:41 PM]  - Fates.INITIALIZE_FRONT: 342 (of 485)
# [INFO][2025/10/18 02:38:41 PM]  - Fates.INITIALIZE_LAZY: 1474 (of 7507)
# [INFO][2025/10/18 02:38:41 PM]  - Fates.TERMINATE_BORDER: 161 (of 317)
# [INFO][2025/10/18 02:38:41 PM]  - Fates.TERMINATE_BACK: 453 (of 624)
# [INFO][2025/10/18 02:38:41 PM]  - Fates.TERMINATE_LAZY: 1870 (of 7347)
# [INFO][2025/10/18 02:38:41 PM]  - TOTAL: 30166 hypotheses
# [INFO][2025/10/18 02:38:41 PM] Completed optimization with 5861 tracks
# [INFO][2025/10/18 02:38:42 PM] Opening HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_01.h5...
# [INFO][2025/10/18 02:38:43 PM] Writing tracks/obj_type_1
# [WARNING][2025/10/18 02:38:43 PM] Removing tracks/obj_type_1.
# [INFO][2025/10/18 02:38:43 PM] Writing dummies/obj_type_1
# [INFO][2025/10/18 02:38:43 PM] Writing LBEP/obj_type_1
# [INFO][2025/10/18 02:38:43 PM] Writing fates/obj_type_1
# [INFO][2025/10/18 02:38:43 PM] Closing HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_01.h5
# [INFO][2025/10/18 02:38:43 PM] Ending BayesianTracker session
# Processing D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\cellpose_SAM_segmented_centers\3_centers\220125_2dfacs_foxa2positive_lateday2_xy02_max_projection_centers.tif...
# [INFO][2025/10/18 02:38:43 PM] Localizing objects from segmentation...
# [INFO][2025/10/18 02:38:43 PM] Processing using 10 workers.
# 100%|██████████| 241/241 [00:10<00:00, 22.32it/s]
# [INFO][2025/10/18 02:38:54 PM] Objects are of type: <class 'dict'>
# [INFO][2025/10/18 02:38:55 PM] ...Found 87836 objects in 241 frames.
# [INFO][2025/10/18 02:38:55 PM] Loaded btrack: C:\Users\davidzi\AppData\Local\anaconda3\envs\btrack-env\Lib\site-packages\btrack\libs\libtracker.DLL
# [INFO][2025/10/18 02:38:55 PM] Starting BayesianTracker session
# [INFO][2025/10/18 02:38:55 PM] Loading configuration file: D:\David\THESIS\code\3.1 cell_config_david.json
# [INFO][2025/10/18 02:38:55 PM] Objects are of type: <class 'list'>
# [INFO][2025/10/18 02:38:56 PM] Starting tracking...
# [INFO][2025/10/18 02:38:56 PM] Update using: ['MOTION']
# [INFO][2025/10/18 02:38:56 PM] Tracking objects in frames 0 to 99 (of 241)...
# [INFO][2025/10/18 02:39:06 PM]  - Timing (Bayesian updates: 111.00ms, Linking: 2.00ms)
# [INFO][2025/10/18 02:39:06 PM]  - Probabilities (Link: 0.99912, Lost: 1.00000)
# [INFO][2025/10/18 02:39:06 PM]  - Stats (Active: 667, Lost: 29391, Conflicts resolved: 365)
# [INFO][2025/10/18 02:39:06 PM] Tracking objects in frames 100 to 199 (of 241)...
# [INFO][2025/10/18 02:39:17 PM]  - Timing (Bayesian updates: 117.00ms, Linking: 3.00ms)
# [INFO][2025/10/18 02:39:17 PM]  - Probabilities (Link: 0.78869, Lost: 0.96065)
# [INFO][2025/10/18 02:39:17 PM]  - Stats (Active: 760, Lost: 68821, Conflicts resolved: 737)
# [INFO][2025/10/18 02:39:17 PM] Tracking objects in frames 200 to 241 (of 241)...
# [INFO][2025/10/18 02:39:22 PM]  - Timing (Bayesian updates: 133.00ms, Linking: 3.00ms)
# [INFO][2025/10/18 02:39:22 PM]  - Probabilities (Link: 0.99992, Lost: 1.00000)
# [INFO][2025/10/18 02:39:22 PM] SUCCESS.
# [INFO][2025/10/18 02:39:22 PM]  - Found 13982 tracks in 241 frames (in 0.0s)
# [INFO][2025/10/18 02:39:22 PM]  - Inserted 8527 dummy objects to fill tracking gaps
# [INFO][2025/10/18 02:39:22 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2025/10/18 02:39:22 PM] Calculating hypotheses (relax: True)...
# [INFO][2025/10/18 02:39:23 PM] Setting up constraints matrix for global optimisation...
# [INFO][2025/10/18 02:39:23 PM] Optimizing...
# [INFO][2025/10/18 02:39:29 PM] Optimization complete. (Solution: optimal)
# [INFO][2025/10/18 02:39:29 PM]  - Fates.FALSE_POSITIVE: 5851 (of 13982)
# [INFO][2025/10/18 02:39:29 PM]  - Fates.LINK: 3964 (of 7650)
# [INFO][2025/10/18 02:39:29 PM]  - Fates.DIVIDE: 669 (of 801)
# [INFO][2025/10/18 02:39:29 PM]  - Fates.INITIALIZE_BORDER: 166 (of 458)
# [INFO][2025/10/18 02:39:29 PM]  - Fates.INITIALIZE_FRONT: 348 (of 584)
# [INFO][2025/10/18 02:39:29 PM]  - Fates.INITIALIZE_LAZY: 2315 (of 12940)
# [INFO][2025/10/18 02:39:29 PM]  - Fates.TERMINATE_BORDER: 169 (of 415)
# [INFO][2025/10/18 02:39:29 PM]  - Fates.TERMINATE_BACK: 441 (of 721)
# [INFO][2025/10/18 02:39:29 PM]  - Fates.TERMINATE_LAZY: 2888 (of 12846)
# [INFO][2025/10/18 02:39:29 PM]  - TOTAL: 50397 hypotheses
# [INFO][2025/10/18 02:39:29 PM] Completed optimization with 10018 tracks
# [INFO][2025/10/18 02:39:30 PM] Opening HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks
PM] Tracking objects in frames 100 to 199 (of 241)...
# [INFO][2025/10/18 02:40:58 PM]  - Timing (Bayesian updates: 7.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:40:58 PM]  - Probabilities (Link: 0.99990, Lost: 0.93769)
# [INFO][2025/10/18 02:40:58 PM]  - Stats (Active: 139, Lost: 5491, Conflicts resolved: 133)
# [INFO][2025/10/18 02:40:58 PM] Tracking objects in frames 200 to 241 (of 241)...
# [INFO][2025/10/18 02:40:58 PM]  - Timing (Bayesian updates: 8.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:40:58 PM]  - Probabilities (Link: 0.99977, Lost: 1.00000)
# [INFO][2025/10/18 02:40:58 PM] SUCCESS.
# [INFO][2025/10/18 02:40:58 PM]  - Found 1045 tracks in 241 frames (in 0.0s)
# [INFO][2025/10/18 02:40:58 PM]  - Inserted 1052 dummy objects to fill tracking gaps
# [INFO][2025/10/18 02:40:58 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2025/10/18 02:40:58 PM] Calculating hypotheses (relax: True)...
# [INFO][2025/10/18 02:40:58 PM] Setting up constraints matrix for global optimisation...
# [INFO][2025/10/18 02:40:58 PM] Optimizing...
# [INFO][2025/10/18 02:40:58 PM] Optimization complete. (Solution: optimal)
# [INFO][2025/10/18 02:40:58 PM]  - Fates.FALSE_POSITIVE: 388 (of 1045)
# [INFO][2025/10/18 02:40:58 PM]  - Fates.LINK: 261 (of 386)
# [INFO][2025/10/18 02:40:58 PM]  - Fates.DIVIDE: 35 (of 38)
# [INFO][2025/10/18 02:40:58 PM]  - Fates.INITIALIZE_BORDER: 29 (of 48)
# [INFO][2025/10/18 02:40:58 PM]  - Fates.INITIALIZE_FRONT: 96 (of 122)
# [INFO][2025/10/18 02:40:58 PM]  - Fates.INITIALIZE_LAZY: 201 (of 875)
# [INFO][2025/10/18 02:40:58 PM]  - Fates.TERMINATE_BORDER: 30 (of 45)
# [INFO][2025/10/18 02:40:58 PM]  - Fates.TERMINATE_BACK: 135 (of 143)
# [INFO][2025/10/18 02:40:58 PM]  - Fates.TERMINATE_LAZY: 196 (of 857)
# [INFO][2025/10/18 02:40:58 PM]  - TOTAL: 3559 hypotheses
# [INFO][2025/10/18 02:40:58 PM] Completed optimization with 784 tracks
# [INFO][2025/10/18 02:40:59 PM] Opening HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_07.h5...
# [INFO][2025/10/18 02:40:59 PM] Writing tracks/obj_type_1
# [WARNING][2025/10/18 02:40:59 PM] Removing tracks/obj_type_1.
# [INFO][2025/10/18 02:40:59 PM] Writing dummies/obj_type_1
# [INFO][2025/10/18 02:40:59 PM] Writing LBEP/obj_type_1
# [INFO][2025/10/18 02:40:59 PM] Writing fates/obj_type_1
# [INFO][2025/10/18 02:40:59 PM] Closing HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_07.h5
# [INFO][2025/10/18 02:40:59 PM] Ending BayesianTracker session
# Processing D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\cellpose_SAM_segmented_centers\3_centers\220125_2dfacs_foxa2positive_lateday2_xy08_max_projection_centers.tif...
# [INFO][2025/10/18 02:40:59 PM] Localizing objects from segmentation...
# [INFO][2025/10/18 02:40:59 PM] Processing using 10 workers.
# 100%|██████████| 241/241 [00:07<00:00, 31.40it/s]
# [INFO][2025/10/18 02:41:07 PM] Objects are of type: <class 'dict'>
# [INFO][2025/10/18 02:41:07 PM] ...Found 12316 objects in 241 frames.
# [INFO][2025/10/18 02:41:07 PM] Loaded btrack: C:\Users\davidzi\AppData\Local\anaconda3\envs\btrack-env\Lib\site-packages\btrack\libs\libtracker.DLL
# [INFO][2025/10/18 02:41:07 PM] Starting BayesianTracker session
# [INFO][2025/10/18 02:41:07 PM] Loading configuration file: D:\David\THESIS\code\3.1 cell_config_david.json
# [INFO][2025/10/18 02:41:07 PM] Objects are of type: <class 'list'>
# [INFO][2025/10/18 02:41:07 PM] Starting tracking...
# [INFO][2025/10/18 02:41:07 PM] Update using: ['MOTION']
# [INFO][2025/10/18 02:41:07 PM] Tracking objects in frames 0 to 99 (of 241)...
# [INFO][2025/10/18 02:41:07 PM]  - Timing (Bayesian updates: 1.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:41:07 PM]  - Probabilities (Link: 0.99327, Lost: 1.00000)
# [INFO][2025/10/18 02:41:07 PM]  - Stats (Active: 74, Lost: 2457, Conflicts resolved: 54)
# [INFO][2025/10/18 02:41:07 PM] Tracking objects in frames 100 to 199 (of 241)...
# [INFO][2025/10/18 02:41:08 PM]  - Timing (Bayesian updates: 2.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:41:08 PM]  - Probabilities (Link: 0.99983, Lost: 1.00000)
# [INFO][2025/10/18 02:41:08 PM]  - Stats (Active: 89, Lost: 4718, Conflicts resolved: 100)
# [INFO][2025/10/18 02:41:08 PM] Tracking objects in frames 200 to 241 (of 241)...
# [INFO][2025/10/18 02:41:08 PM]  - Timing (Bayesian updates: 2.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:41:08 PM]  - Probabilities (Link: 0.99936, Lost: 1.00000)
# [INFO][2025/10/18 02:41:08 PM] SUCCESS.
# [INFO][2025/10/18 02:41:08 PM]  - Found 874 tracks in 241 frames (in 0.0s)
# [INFO][2025/10/18 02:41:08 PM]  - Inserted 1008 dummy objects to fill tracking gaps
# [INFO][2025/10/18 02:41:08 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2025/10/18 02:41:08 PM] Calculating hypotheses (relax: True)...
# [INFO][2025/10/18 02:41:08 PM] Setting up constraints matrix for global optimisation...
# [INFO][2025/10/18 02:41:08 PM] Optimizing...
# [INFO][2025/10/18 02:41:08 PM] Optimization complete. (Solution: optimal)
# [INFO][2025/10/18 02:41:08 PM]  - Fates.FALSE_POSITIVE: 385 (of 874)
# [INFO][2025/10/18 02:41:08 PM]  - Fates.LINK: 211 (of 282)
# [INFO][2025/10/18 02:41:08 PM]  - Fates.DIVIDE: 17 (of 19)
# [INFO][2025/10/18 02:41:08 PM]  - Fates.INITIALIZE_BORDER: 23 (of 49)
# [INFO][2025/10/18 02:41:08 PM]  - Fates.INITIALIZE_FRONT: 50 (of 69)
# [INFO][2025/10/18 02:41:08 PM]  - Fates.INITIALIZE_LAZY: 171 (of 756)
# [INFO][2025/10/18 02:41:08 PM]  - Fates.TERMINATE_BORDER: 22 (of 49)
# [INFO][2025/10/18 02:41:08 PM]  - Fates.TERMINATE_BACK: 70 (of 77)
# [INFO][2025/10/18 02:41:08 PM]  - Fates.TERMINATE_LAZY: 169 (of 748)
# [INFO][2025/10/18 02:41:08 PM]  - TOTAL: 2923 hypotheses
# [INFO][2025/10/18 02:41:08 PM] Completed optimization with 663 tracks
# [INFO][2025/10/18 02:41:08 PM] Opening HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_08.h5...
# [INFO][2025/10/18 02:41:08 PM] Writing tracks/obj_type_1
# [WARNING][2025/10/18 02:41:08 PM] Removing tracks/obj_type_1.
# [INFO][2025/10/18 02:41:08 PM] Writing dummies/obj_type_1
# [INFO][2025/10/18 02:41:08 PM] Writing LBEP/obj_type_1
# [INFO][2025/10/18 02:41:08 PM] Writing fates/obj_type_1
# [INFO][2025/10/18 02:41:08 PM] Closing HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_08.h5
# [INFO][2025/10/18 02:41:08 PM] Ending BayesianTracker session
# Processing D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\cellpose_SAM_segmented_centers\3_centers\220125_2dfacs_foxa2positive_lateday2_xy09_max_projection_centers.tif...
# [INFO][2025/10/18 02:41:08 PM] Localizing objects from segmentation...
# [INFO][2025/10/18 02:41:08 PM] Processing using 10 workers.
# 100%|██████████| 241/241 [00:07<00:00, 30.25it/s]
# [INFO][2025/10/18 02:41:16 PM] Objects are of type: <class 'dict'>
# [INFO][2025/10/18 02:41:17 PM] ...Found 12391 objects in 241 frames.
# [INFO][2025/10/18 02:41:17 PM] Loaded btrack: C:\Users\davidzi\AppData\Local\anaconda3\envs\btrack-env\Lib\site-packages\btrack\libs\libtracker.DLL
# [INFO][2025/10/18 02:41:17 PM] Starting BayesianTracker session
# [INFO][2025/10/18 02:41:17 PM] Loading configuration file: D:\David\THESIS\code\3.1 cell_config_david.json
# [INFO][2025/10/18 02:41:17 PM] Objects are of type: <class 'list'>
# [INFO][2025/10/18 02:41:17 PM] Starting tracking...
# [INFO][2025/10/18 02:41:17 PM] Update using: ['MOTION']
# [INFO][2025/10/18 02:41:17 PM] Tracking objects in frames 0 to 99 (of 241)...
# [INFO][2025/10/18 02:41:17 PM]  - Timing (Bayesian updates: 1.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:41:17 PM]  - Probabilities (Link: 0.99999, Lost: 0.51192)
# [INFO][2025/10/18 02:41:17 PM]  - Stats (Active: 62, Lost: 2380, Conflicts resolved: 63)
# [INFO][2025/10/18 02:41:17 PM] Tracking objects in frames 100 to 199 (of 241)...
# [INFO][2025/10/18 02:41:17 PM]  - Timing (Bayesian updates: 2.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:41:17 PM]  - Probabilities (Link: 0.99170, Lost: 0.96884)
# [INFO][2025/10/18 02:41:17 PM]  - Stats (Active: 85, Lost: 4987, Conflicts resolved: 135)
# [INFO][2025/10/18 02:41:17 PM] Tracking objects in frames 200 to 241 (of 241)...
# [INFO][2025/10/18 02:41:17 PM]  - Timing (Bayesian updates: 2.00ms, Linking: 1.00ms)
# [INFO][2025/10/18 02:41:17 PM]  - Probabilities (Link: 0.99966, Lost: 0.99440)
# [INFO][2025/10/18 02:41:17 PM] SUCCESS.
# [INFO][2025/10/18 02:41:17 PM]  - Found 929 tracks in 241 frames (in 0.0s)
# [INFO][2025/10/18 02:41:17 PM]  - Inserted 1003 dummy objects to fill tracking gaps
# [INFO][2025/10/18 02:41:17 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2025/10/18 02:41:17 PM] Calculating hypotheses (relax: True)...
# [INFO][2025/10/18 02:41:17 PM] Setting up constraints matrix for global optimisation...
# [INFO][2025/10/18 02:41:17 PM] Optimizing...
# [INFO][2025/10/18 02:41:17 PM] Optimization complete. (Solution: optimal)
# [INFO][2025/10/18 02:41:17 PM]  - Fates.FALSE_POSITIVE: 449 (of 929)
# [INFO][2025/10/18 02:41:17 PM]  - Fates.LINK: 197 (of 304)
# [INFO][2025/10/18 02:41:17 PM]  - Fates.DIVIDE: 26 (of 26)
# [INFO][2025/10/18 02:41:17 PM]  - Fates.INITIALIZE_BORDER: 15 (of 25)
# [INFO][2025/10/18 02:41:17 PM]  - Fates.INITIALIZE_FRONT: 54 (of 73)
# [INFO][2025/10/18 02:41:17 PM]  - Fates.INITIALIZE_LAZY: 162 (of 831)
# [INFO][2025/10/18 02:41:17 PM]  - Fates.TERMINATE_BORDER: 16 (of 28)
# [INFO][2025/10/18 02:41:17 PM]  - Fates.TERMINATE_BACK: 69 (of 82)
# [INFO][2025/10/18 02:41:17 PM]  - Fates.TERMINATE_LAZY: 172 (of 819)
# [INFO][2025/10/18 02:41:17 PM]  - TOTAL: 3117 hypotheses
# [INFO][2025/10/18 02:41:17 PM] Completed optimization with 732 tracks
# [INFO][2025/10/18 02:41:17 PM] Opening HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_09.h5...
# [INFO][2025/10/18 02:41:17 PM] Writing tracks/obj_type_1
# [WARNING][2025/10/18 02:41:17 PM] Removing tracks/obj_type_1.
# [INFO][2025/10/18 02:41:17 PM] Writing dummies/obj_type_1
# [INFO][2025/10/18 02:41:17 PM] Writing LBEP/obj_type_1
# [INFO][2025/10/18 02:41:17 PM] Writing fates/obj_type_1
# [INFO][2025/10/18 02:41:17 PM] Closing HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_09.h5
# [INFO][2025/10/18 02:41:17 PM] Ending BayesianTracker session
# Processing D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\cellpose_SAM_segmented_centers\3_centers\220125_2dfacs_foxa2positive_lateday2_xy10_max_projection_centers.tif...
# [INFO][2025/10/18 02:41:18 PM] Localizing objects from segmentation...
# [INFO][2025/10/18 02:41:18 PM] Processing using 10 workers.
# 100%|██████████| 241/241 [00:07<00:00, 30.84it/s]
# [INFO][2025/10/18 02:41:26 PM] Objects are of type: <class 'dict'>
# [INFO][2025/10/18 02:41:26 PM] ...Found 8858 objects in 241 frames.
# [INFO][2025/10/18 02:41:26 PM] Loaded btrack: C:\Users\davidzi\AppData\Local\anaconda3\envs\btrack-env\Lib\site-packages\btrack\libs\libtracker.DLL
# [INFO][2025/10/18 02:41:26 PM] Starting BayesianTracker session
# [INFO][2025/10/18 02:41:26 PM] Loading configuration file: D:\David\THESIS\code\3.1 cell_config_david.json
# [INFO][2025/10/18 02:41:26 PM] Objects are of type: <class 'list'>
# [INFO][2025/10/18 02:41:26 PM] Starting tracking...
# [INFO][2025/10/18 02:41:26 PM] Update using: ['MOTION']
# [INFO][2025/10/18 02:41:26 PM] Tracking objects in frames 0 to 99 (of 241)...
# [INFO][2025/10/18 02:41:26 PM]  - Timing (Bayesian updates: 2.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:41:26 PM]  - Probabilities (Link: 0.99961, Lost: 1.00000)
# [INFO][2025/10/18 02:41:26 PM]  - Stats (Active: 49, Lost: 2006, Conflicts resolved: 30)
# [INFO][2025/10/18 02:41:26 PM] Tracking objects in frames 100 to 199 (of 241)...
# [INFO][2025/10/18 02:41:26 PM]  - Timing (Bayesian updates: 1.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:41:26 PM]  - Probabilities (Link: 0.99999, Lost: 0.67095)
# [INFO][2025/10/18 02:41:26 PM]  - Stats (Active: 68, Lost: 4243, Conflicts resolved: 92)
# [INFO][2025/10/18 02:41:26 PM] Tracking objects in frames 200 to 241 (of 241)...
# [INFO][2025/10/18 02:41:26 PM]  - Timing (Bayesian updates: 2.00ms, Linking: 0.00ms)
# [INFO][2025/10/18 02:41:26 PM]  - Probabilities (Link: 0.50303, Lost: 1.00000)
# [INFO][2025/10/18 02:41:26 PM] SUCCESS.
# [INFO][2025/10/18 02:41:26 PM]  - Found 809 tracks in 241 frames (in 0.0s)
# [INFO][2025/10/18 02:41:26 PM]  - Inserted 939 dummy objects to fill tracking gaps
# [INFO][2025/10/18 02:41:26 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2025/10/18 02:41:26 PM] Calculating hypotheses (relax: True)...
# [INFO][2025/10/18 02:41:26 PM] Setting up constraints matrix for global optimisation...
# [INFO][2025/10/18 02:41:26 PM] Optimizing...
# [INFO][2025/10/18 02:41:26 PM] Optimization complete. (Solution: optimal)
# [INFO][2025/10/18 02:41:26 PM]  - Fates.FALSE_POSITIVE: 430 (of 809)
# [INFO][2025/10/18 02:41:26 PM]  - Fates.LINK: 136 (of 220)
# [INFO][2025/10/18 02:41:26 PM]  - Fates.DIVIDE: 21 (of 23)
# [INFO][2025/10/18 02:41:26 PM]  - Fates.INITIALIZE_BORDER: 11 (of 34)
# [INFO][2025/10/18 02:41:26 PM]  - Fates.INITIALIZE_FRONT: 27 (of 43)
# [INFO][2025/10/18 02:41:26 PM]  - Fates.INITIALIZE_LAZY: 163 (of 732)
# [INFO][2025/10/18 02:41:26 PM]  - Fates.TERMINATE_BORDER: 8 (of 32)
# [INFO][2025/10/18 02:41:26 PM]  - Fates.TERMINATE_BACK: 60 (of 78)
# [INFO][2025/10/18 02:41:26 PM]  - Fates.TERMINATE_LAZY: 154 (of 699)
# [INFO][2025/10/18 02:41:26 PM]  - TOTAL: 2670 hypotheses
# [INFO][2025/10/18 02:41:26 PM] Completed optimization with 673 tracks
# [INFO][2025/10/18 02:41:26 PM] Opening HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_10.h5...
# [INFO][2025/10/18 02:41:26 PM] Writing tracks/obj_type_1
# [WARNING][2025/10/18 02:41:26 PM] Removing tracks/obj_type_1.
# [INFO][2025/10/18 02:41:26 PM] Writing dummies/obj_type_1
# [INFO][2025/10/18 02:41:26 PM] Writing LBEP/obj_type_1
# [INFO][2025/10/18 02:41:26 PM] Writing fates/obj_type_1
# [INFO][2025/10/18 02:41:26 PM] Closing HDF file: D:\David\endoderm_migration\raw_data\2025_01_22_2DFACS_FOXA2positive_lateday2\btrack_tracks_centers\tracks_10.h5
# [INFO][2025/10/18 02:41:26 PM] Ending BayesianTracker session
